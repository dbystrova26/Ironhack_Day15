# %% [markdown]
# # MCP Introduction with LangChain
#
# This notebook demonstrates connecting to MCP servers and integrating them with LangChain agents using the `langchain-mcp-adapters` package.

# %% [markdown]
# ## Setup

# %% [markdown]
# !pip install langchain langchain-openai langchain-mcp-adapters langgraph mcp python-dotenv -q

# %%
# !pip install langchain langchain-openai langchain-mcp-adapters langgraph mcp python-dotenv -q
# Out:
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\dbyst\miniconda3\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Load environment variables from .env file
load_dotenv()

# Verify API key is loaded
if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("OPENAI_API_KEY not found in environment variables. Please create a .env file with your API key.")

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %% [markdown]
# ## LangChain Integration with MCP
#
# ### Using langchain-mcp-adapters
#
# LangChain provides the `langchain-mcp-adapters` package, which offers a seamless way to connect LangChain applications to MCP servers. This package includes `MultiServerMCPClient`, which allows you to connect to multiple MCP servers and load their tools, resources, and prompts into LangChain agents.
#
# ### Key Benefits
#
# - **Standardized Protocol**: Work with one protocol instead of juggling multiple APIs
# - **Multiple Servers**: Connect to multiple MCP servers simultaneously
# - **LangChain Native**: Tools, resources, and prompts are automatically LangChain-compatible
# - **Stateless by Default**: Each tool call creates a fresh session, no context manager needed
# - **Tool Interceptors**: Middleware pattern for customizing tool behavior
#
# ### The LangChain Documentation MCP Server
#
# We'll use the LangChain documentation MCP server as our example:
# - **MCP Server URL**: `https://docs.langchain.com/mcp`
# - **Documentation Index**: `https://docs.langchain.com/llms.txt`
# - **Transport**: HTTP (not stdio)
# - **Provides**: Access to LangChain, LangGraph, and LangSmith documentation
#
# This MCP server allows you to query the latest LangChain documentation programmatically, making it perfect for building agents that can answer questions about LangChain features and APIs.

# %% [markdown]
# ### Connecting to the LangChain Documentation MCP Server
#
# Now let's connect to the LangChain documentation MCP server using HTTP transport.
#
# `MultiServerMCPClient` accepts a dictionary where keys are server names and values are configuration dicts specifying `transport` and connection details:

# %%
import sys
print(sys.executable)  # Will likely show: C:\Users\dbyst\miniconda3\python.exe
# Out:
# c:\Users\dbyst\miniconda3\python.exe

# %%
import sys, subprocess
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "--upgrade", "--force-reinstall",
    "pydantic>=2.10.0"
], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\dbyst\\miniconda3\\python.exe', '-m', 'pip', 'install', '--upgrade', '--force-reinstall', 'pydantic>=2.10.0'], returncode=0)

# %%
import sys, subprocess

# Wipe pydantic and pydantic-core completely, then reinstall together
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "--upgrade", "--force-reinstall",
    "pydantic>=2.10.0",
    "pydantic-core>=2.27.0",
    "mcp",
    "langchain-mcp-adapters"
], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\dbyst\\miniconda3\\python.exe', '-m', 'pip', 'install', '--upgrade', '--force-reinstall', 'pydantic>=2.10.0', 'pydantic-core>=2.27.0', 'mcp', 'langchain-mcp-adapters'], returncode=0)

# %%
import pydantic
print(pydantic.__version__)  # Should show 2.10+
# Out:
# 2.10.3

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
# Out:
# ---------------------------------------------------------------------------
#
# ImportError                               Traceback (most recent call last)
#
# Cell In[22], line 1
#
# ----> 1 from langchain_mcp_adapters.client import MultiServerMCPClient
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_mcp_adapters\client.py:16
#
#      14 from langchain_core.messages import AIMessage, HumanMessage
#
#      15 from langchain_core.tools import BaseTool
#
# ---> 16 from mcp import ClientSession
#
#      18 from langchain_mcp_adapters.callbacks import CallbackContext, Callbacks
#
#      19 from langchain_mcp_adapters.interceptors import ToolCallInterceptor
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\__init__.py:4
#
#       2 from .client.session_group import ClientSessionGroup
#
#       3 from .client.stdio import StdioServerParameters, stdio_client
#
# ----> 4 from .server.session import ServerSession
#
#       5 from .server.stdio import stdio_server
#
#       6 from .shared.exceptions import McpError, UrlElicitationRequiredError
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\server\__init__.py:1
#
# ----> 1 from .fastmcp import FastMCP
#
#       2 from .lowlevel import NotificationOptions, Server
#
#       3 from .models import InitializationOptions
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\server\fastmcp\__init__.py:7
#
#       3 from importlib.metadata import version
#
#       5 from mcp.types import Icon
#
# ----> 7 from .server import Context, FastMCP
#
#       8 from .utilities.types import Audio, Image
#
#      10 __version__ = version("mcp")
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\server\fastmcp\server.py:22
#
#      20 from pydantic import BaseModel
#
#      21 from pydantic.networks import AnyUrl
#
# ---> 22 from pydantic_settings import BaseSettings, SettingsConfigDict
#
#      23 from starlette.applications import Starlette
#
#      24 from starlette.middleware import Middleware
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\pydantic_settings\__init__.py:2
#
#       1 from .exceptions import SettingsError
#
# ----> 2 from .main import BaseSettings, CliApp, SettingsConfigDict
#
#       3 from .sources import (
#
#       4     CLI_SUPPRESS,
#
#       5     AWSSecretsManagerSettingsSource,
#
#    (...)     30     get_subcommand,
#
#      31 )
#
#      32 from .version import VERSION
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\pydantic_settings\main.py:17
#
#      15 from pydantic._internal._signature import _field_name_for_signature
#
#      16 from pydantic._internal._utils import deep_update, is_model_class
#
# ---> 17 from pydantic.dataclasses import is_pydantic_dataclass
#
#      18 from pydantic.main import BaseModel
#
#      20 from .exceptions import SettingsError
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\pydantic\dataclasses.py:15
#
#      12 from typing_extensions import TypeGuard, dataclass_transform
#
#      14 from ._internal import _config, _decorators, _mock_val_ser, _namespace_utils, _typing_extra
#
# ---> 15 from ._internal import _dataclasses as _pydantic_dataclasses
#
#      16 from ._migration import getattr_migration
#
#      17 from .config import ConfigDict
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\pydantic\_internal\_dataclasses.py:28
#
#      26 from . import _config, _decorators
#
#      27 from ._fields import collect_dataclass_fields
#
# ---> 28 from ._generate_schema import GenerateSchema, InvalidSchemaError
#
#      29 from ._generics import get_standard_typevars_map
#
#      30 from ._mock_val_ser import set_dataclass_mocks
#
#
#
# ImportError: cannot import name 'InvalidSchemaError' from 'pydantic._internal._generate_schema' (c:\Users\dbyst\miniconda3\Lib\site-packages\pydantic\_internal\_generate_schema.py)

# %%
import sys, subprocess
result = subprocess.run([
    sys.executable, "-m", "pip", "show", "-f", "pydantic"
], capture_output=True, text=True)
print(result.stdout[:3000])
# Out:
# Name: pydantic
# Version: 2.13.4
# Summary: Data validation using Python type hints
# Home-page: https://github.com/pydantic/pydantic
# Author:
# Author-email: Samuel Colvin <s@muelcolvin.com>, Eric Jolibois <em.jolibois@gmail.com>, Hasan Ramezani <hasan.r67@gmail.com>, Adrian Garcia Badaracco <1755071+adriangb@users.noreply.github.com>, Terrence Dorsey <terry@pydantic.dev>, David Montague <david@pydantic.dev>, Serge Matveenko <lig@countzero.co>, Marcelo Trylesinski <marcelotryle@gmail.com>, Sydney Runkle <sydneymarierunkle@gmail.com>, David Hewitt <mail@davidhewitt.dev>, Alex Hall <alex.mojaki@gmail.com>, Victorien Plot <contact@vctrn.dev>
# License-Expression: MIT
# Location: c:\Users\dbyst\miniconda3\Lib\site-packages
# Requires: annotated-types, pydantic-core, typing-extensions, typing-inspection
# Required-by: anthropic, chromadb, conda-anaconda-tos, fastapi, gradio, langchain, langchain-anthropic, langchain-classic, langchain-core, langgraph, langsmith, mcp, openai, pydantic-settings
# Files:
#   pydantic-2.13.4.dist-info\INSTALLER
#   pydantic-2.13.4.dist-info\METADATA
#   pydantic-2.13.4.dist-info\RECORD
#   pydantic-2.13.4.dist-info\REQUESTED
#   pydantic-2.13.4.dist-info\WHEEL
#   pydantic-2.13.4.dist-info\licenses\LICENSE
#   pydantic\__init__.py
#   pydantic\__pycache__\__init__.cpython-313.pyc
#   pydantic\__pycache__\_migration.cpython-313.pyc
#   pydantic\__pycache__\alias_generators.cpython-313.pyc
#   pydantic\__pycache__\aliases.cpython-313.pyc
#   pydantic\__pycache__\annotated_handlers.cpython-313.pyc
#   pydantic\__pycache__\class_validators.cpython-313.pyc
#   pydantic\__pycache__\color.cpython-313.pyc
#   pydantic\__pycache__\config.cpython-313.pyc
#   pydantic\__pycache__\dataclasses.cpython-313.pyc
#   pydantic\__pycache__\datetime_parse.cpython-313.pyc
#   pydantic\__pycache__\decorator.cpython-313.pyc
#   pydantic\__pycache__\env_settings.cpython-313.pyc
#   pydantic\__pycache__\error_wrappers.cpython-313.pyc
#   pydantic\__pycache__\errors.cpython-313.pyc
#   pydantic\__pycache__\fields.cpython-313.pyc
#   pydantic\__pycache__\functional_serializers.cpython-313.pyc
#   pydantic\__pycache__\functional_validators.cpython-313.pyc
#   pydantic\__pycache__\generics.cpython-313.pyc
#   pydantic\__pycache__\json.cpython-313.pyc
#   pydantic\__pycache__\json_schema.cpython-313.pyc
#   pydantic\__pycache__\main.cpython-313.pyc
#   pydantic\__pycache__\mypy.cpython-313.pyc
#   pydantic\__pycache__\networks.cpython-313.pyc
#   pydantic\__pycache__\parse.cpython-313.pyc
#   pydantic\__pycache__\root_model.cpython-313.pyc
#   pydantic\__pycache__\schema.cpython-313.pyc
#   pydantic\__pycache__\tools.cpython-313.pyc
#   pydantic\__pycache__\type_adapter.cpython-313.pyc
#   pydantic\__pycache__\types.cpython-313.pyc
#   pydantic\__pycache__\typing.cpython-313.pyc
#   pydantic\__pycache__\utils.cpython-313.pyc
#   pydantic\__pycache__\validate_call_decorator.cpython-313.pyc
#   pydantic\__pycache__\validators.cpython-313.pyc
#   pydantic\__pycache__\version.cpython-313.pyc
#   pydantic\__pycache__\warnings.cpython-313.pyc
#   pydantic\_i

# %%
import pydantic._internal._generate_schema as gs
print([x for x in dir(gs) if 'Schema' in x or 'Invalid' in x])
# Out:
# ['CallbackGetCoreSchemaHandler', 'CoreSchema', 'GenerateSchema', 'GetCoreSchemaFunction', 'GetCoreSchemaHandler', 'GetJsonSchemaHandler', 'JsonSchemaExtraCallable', 'JsonSchemaValue', 'MockCoreSchema', 'ModifyCoreSchemaWrapHandler', 'PydanticSchemaGenerationError']

# %%
import sys, subprocess
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "--force-reinstall",
    "mcp==1.3.0",
    "langchain-mcp-adapters"
], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\dbyst\\miniconda3\\python.exe', '-m', 'pip', 'install', '--force-reinstall', 'mcp==1.3.0', 'langchain-mcp-adapters'], returncode=0)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

# %%
import subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "--upgrade", "pydantic>=2.10", "mcp", "langchain-mcp-adapters"], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\dbyst\\miniconda3\\python.exe', '-m', 'pip', 'install', '--upgrade', 'pydantic>=2.10', 'mcp', 'langchain-mcp-adapters'], returncode=0)

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import asyncio

# Configure the LangChain documentation MCP server
# MultiServerMCPClient takes a dict of server configs
# Each config specifies transport type and connection details
mcp_client = MultiServerMCPClient({
    "langchain-docs": {
        "transport": "http",
        "url": "https://docs.langchain.com/mcp"
    }
})

print("MCP client configured for LangChain documentation server")
print(f"Server: langchain-docs → https://docs.langchain.com/mcp")
# Out:
# MCP client configured for LangChain documentation server
# Server: langchain-docs → https://docs.langchain.com/mcp

# %% [markdown]
# ### Loading MCP Tools into LangChain
#
# The `get_tools()` method retrieves all tools from connected MCP servers and converts them to LangChain-compatible tools.
#
# **Note:** `MultiServerMCPClient` is stateless by default — each call to `get_tools()` internally creates and tears down fresh sessions automatically. No `async with` context manager is needed:

# %%
# Load tools from the MCP server
# The client is stateless: get_tools() creates ephemeral sessions under the hood
# mcp_tools = await mcp_client.get_tools() await is used to pause and wait for async operations — things that take time, like network requests, file reads, or database queries. You use it when a function is defined with async def, meaning it returns a "promise" of a result rather than the result itself.
mcp_tools = mcp_client.get_tools()

print(f"Loaded {len(mcp_tools)} tools from MCP server(s)")
print("\nAvailable tools:")
for tool in mcp_tools:
    print(f"  - {tool.name}: {tool.description[:80]}...")
# Out:
# Loaded 0 tools from MCP server(s)
#
# Available tools:

# %%
mcp_tools = mcp_client.get_tools()

print(f"Loaded {len(mcp_tools)} tools from MCP server(s)")
print("\nAvailable tools:")
for tool in mcp_tools:
    print(f"  - {tool.name}: {tool.description[:80]}...")
# Out:
# Loaded 0 tools from MCP server(s)
#
# Available tools:

# %% [markdown]
# !!! https://docs.langchain.com/mcp is not a real MCP server endpoint — it doesn't exist as a live service you can connect to. That's why you get 0 tools. The LangChain docs MCP server needs to be run locally using their mcpdoc tool.
#
# pip install uv
# uvx --from mcpdoc mcpdoc --urls "LangChain:https://python.langchain.com/llms.txt" --transport sse --port 8082 --host localhost
#
# from langchain_mcp_adapters.client import MultiServerMCPClient
#
# mcp_client = MultiServerMCPClient({
#     "langchain-docs": {
#         "transport": "sse",
#         "url": "http://localhost:8082/sse"
#     }
# })
#
# mcp_tools = mcp_client.get_tools()
# print(f"Loaded {len(mcp_tools)} tools")
# for tool in mcp_tools:
#     print(f"  - {tool.name}: {tool.description[:80]}")

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

mcp_client = MultiServerMCPClient({
    "langchain-docs": {
        "transport": "sse",
        "url": "http://localhost:8082/sse"
    }
})

mcp_tools = mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} tools")
for tool in mcp_tools:
    print(f"  - {tool.name}: {tool.description[:80]}")
# Out:
# Loaded 0 tools

# %%
import urllib.request
try:
    r = urllib.request.urlopen("http://localhost:8082")
    print(r.status, r.read(500))
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: <urlopen error [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte>

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient

async def load():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        tools = client.get_tools()  # no await
        return tools

mcp_tools = asyncio.get_event_loop().run_until_complete(load())
print(f"Loaded {len(mcp_tools)} tools")
for tool in mcp_tools:
    print(f"  - {tool.name}: {tool.description[:80]}")
# Out:
# Loaded 2 tools
#   - list_doc_sources: List all available documentation sources.
#
# This is the first tool you should cal
#   - fetch_docs: Fetch and parse documentation from a given URL or local file.
#
# Use this tool aft

# %% [markdown]
# ### Using MCP Tools with LangChain Agents
#
# Now let's create a LangChain agent that can use these MCP tools to query the LangChain documentation.
#
# We use `create_react_agent` from `langgraph.prebuilt` with the `prompt` parameter to set the system message:

# %%
import sys, subprocess
subprocess.run([
    sys.executable, "-m", "pip", "install",
    "--upgrade",
    "langchain",
    "langchain-core",
    "langchain-community",
    "langgraph",
    "langsmith"
], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\dbyst\\miniconda3\\python.exe', '-m', 'pip', 'install', '--upgrade', 'langchain', 'langchain-core', 'langchain-community', 'langgraph', 'langsmith'], returncode=0)

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient

async def load():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        tools = client.get_tools()
        return tools

mcp_tools = asyncio.get_event_loop().run_until_complete(load())
print(f"Loaded {len(mcp_tools)} tools")
for tool in mcp_tools:
    print(f"  - {tool.name}: {tool.description[:80]}")
# Out:
# Loaded 2 tools
#   - list_doc_sources: List all available documentation sources.
#
# This is the first tool you should cal
#   - fetch_docs: Fetch and parse documentation from a given URL or local file.
#
# Use this tool aft

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()  # loads variables from .env file

llm = ChatOpenAI(model="gpt-4o", temperature=0)
print("LLM ready:", llm.model_name)
# Out:
# LLM ready: gpt-4o

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain_mcp_adapters.client import MultiServerMCPClient

async def load():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        return client.get_tools()  # no await

mcp_tools = asyncio.get_event_loop().run_until_complete(load())

agent = create_agent(
    model=llm,
    tools=mcp_tools,
    system_prompt="You are a helpful assistant that can answer questions about LangChain, LangGraph, and LangSmith by searching the official documentation."
)

print(f"Agent created with {len(mcp_tools)} tools")
print(f"Tools: {[tool.name for tool in mcp_tools]}")
# Out:
# Agent created with 2 tools
# Tools: ['list_doc_sources', 'fetch_docs']

# %% [markdown]
# ### Querying LangChain Documentation
#
# Let's test the agent by asking it questions about LangChain:

# %%
llm = ChatAnthropic(model="claude-sonnet-4-6", temperature=0)
print("LLM ready:", llm.model)
# Out:
# LLM ready: claude-sonnet-4-6

# %%
agent = create_agent(
    model=llm,
    tools=mcp_tools,
    system_prompt="You are a helpful assistant that can answer questions about LangChain, LangGraph, and LangSmith by searching the official documentation."
)
print("Agent rebuilt with claude-sonnet-4-6")
# Out:
# Agent rebuilt with claude-sonnet-4-6

# %%
question = "How do I create a LangChain agent with tools?"
print(f"Question: {question}\n")

result = await agent.ainvoke({
    "messages": [HumanMessage(content=question)]
})

print(f"Answer: {result['messages'][-1].content}")
# Out:
# Question: How do I create a LangChain agent with tools?
# ---------------------------------------------------------------------------
#
# ClosedResourceError                       Traceback (most recent call last)
#
# Cell In[21], line 4
#
#       1 question = "How do I create a LangChain agent with tools?"
#
#       2 print(f"Question: {question}\n")
#
# ----> 4 result = await agent.ainvoke({
#
#       5     "messages": [HumanMessage(content=question)]
#
#       6 })
#
#       8 print(f"Answer: {result['messages'][-1].content}")
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\pregel\main.py:3535, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#
#    3532             chunks.append(chunk)
#
#    3533 else:
#
#    3534     # v1: collect interrupts from updates stream
#
# -> 3535     async for chunk in self.astream(
#
#    3536         input,
#
#    3537         config,
#
#    3538         context=context,
#
#    3539         stream_mode=(
#
#    3540             ["updates", "values"] if stream_mode == "values" else stream_mode
#
#    3541         ),
#
#    3542         print_mode=print_mode,
#
#    3543         output_keys=output_keys,
#
#    3544         interrupt_before=interrupt_before,
#
#    3545         interrupt_after=interrupt_after,
#
#    3546         durability=durability,
#
#    3547         **kwargs,
#
#    3548     ):
#
#    3549         if stream_mode == "values":
#
#    3550             if len(chunk) == 2:
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\pregel\main.py:3181, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#
#    3179 for task in await loop.amatch_cached_writes():
#
#    3180     loop.output_writes(task.id, task.writes, cached=True)
#
# -> 3181 async for _ in runner.atick(
#
#    3182     [t for t in loop.tasks.values() if not t.writes],
#
#    3183     timeout=self.step_timeout,
#
#    3184     get_waiter=get_waiter,
#
#    3185     schedule_task=loop.aaccept_push,
#
#    3186 ):
#
#    3187     # emit output
#
#    3188     for o in _output(
#
#    3189         stream_mode,
#
#    3190         print_mode,
#
#    (...)   3196         _state_mapper,
#
#    3197     ):
#
#    3198         yield o
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#
#     302 t = tasks[0]
#
#     303 try:
#
# --> 304     await arun_with_retry(
#
#     305         t,
#
#     306         retry_policy,
#
#     307         stream=self.use_astream,
#
#     308         configurable={
#
#     309             CONFIG_KEY_CALL: partial(
#
#     310                 _acall,
#
#     311                 weakref.ref(t),
#
#     312                 stream=self.use_astream,
#
#     313                 retry_policy=retry_policy,
#
#     314                 futures=weakref.ref(futures),
#
#     315                 schedule_task=schedule_task,
#
#     316                 submit=self.submit,
#
#     317                 loop=loop,
#
#     318             ),
#
#     319         },
#
#     320     )
#
#     321     self.commit(t, None)
#
#     322 except Exception as exc:
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\pregel\_retry.py:242, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#
#     240         break
#
#     241     else:
#
# --> 242         return await task.proc.ainvoke(task.input, config)
#
#     243 except ParentCommand as exc:
#
#     244     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\_internal\_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#
#     703     # run in context
#
#     704     with set_config_context(config, run) as context:
#
# --> 705         input = await asyncio.create_task(
#
#     706             step.ainvoke(input, config, **kwargs), context=context
#
#     707         )
#
#     708 else:
#
#     709     input = await step.ainvoke(input, config, **kwargs)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\futures.py:286, in Future.__await__(self)
#
#     284 if not self.done():
#
#     285     self._asyncio_future_blocking = True
#
# --> 286     yield self  # This tells Task to wait for completion.
#
#     287 if not self.done():
#
#     288     raise RuntimeError("await wasn't used with future")
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#
#     373 def __wakeup(self, future):
#
#     374     try:
#
# --> 375         future.result()
#
#     376     except BaseException as exc:
#
#     377         # This may also be a cancellation.
#
#     378         self.__step(exc)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\futures.py:199, in Future.result(self)
#
#     197 self.__log_traceback = False
#
#     198 if self._exception is not None:
#
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#
#     200 return self._result
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#
#     304         result = coro.send(None)
#
#     305     else:
#
# --> 306         result = coro.throw(exc)
#
#     307 except StopIteration as exc:
#
#     308     if self._must_cancel:
#
#     309         # Task is cancelled right before coro stops.
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#
#     471         await run_manager.on_chain_end(ret)
#
#     472 else:
#
# --> 473     ret = await self.afunc(*args, **kwargs)
#
#     474 if self.recurse and isinstance(ret, Runnable):
#
#     475     return await ret.ainvoke(input, config)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:857, in ToolNode._afunc(self, input, config, runtime)
#
#     855 for call, tool_runtime in zip(tool_calls, tool_runtimes, strict=False):
#
#     856     coros.append(self._arun_one(call, input_type, tool_runtime))  # type: ignore[arg-type]
#
# --> 857 outputs = await asyncio.gather(*coros)
#
#     859 return self._combine_tool_outputs(outputs, input_type)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#
#     373 def __wakeup(self, future):
#
#     374     try:
#
# --> 375         future.result()
#
#     376     except BaseException as exc:
#
#     377         # This may also be a cancellation.
#
#     378         self.__step(exc)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#
#     304         result = coro.send(None)
#
#     305     else:
#
# --> 306         result = coro.throw(exc)
#
#     307 except StopIteration as exc:
#
#     308     if self._must_cancel:
#
#     309         # Task is cancelled right before coro stops.
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:1192, in ToolNode._arun_one(self, call, input_type, tool_runtime)
#
#    1188 config = tool_runtime.config
#
#    1190 if self._awrap_tool_call is None and self._wrap_tool_call is None:
#
#    1191     # No wrapper - execute directly
#
# -> 1192     return await self._execute_tool_async(tool_request, input_type, config)
#
#    1194 # Define async execute callable that can be called multiple times
#
#    1195 async def execute(req: ToolCallRequest) -> ToolMessage | Command:
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:1152, in ToolNode._execute_tool_async(self, request, input_type, config)
#
#    1149     raise
#
#    1151 # Error is handled - create error ToolMessage
#
# -> 1152 content = _handle_tool_error(e, flag=self._handle_tool_errors)
#
#    1153 return ToolMessage(
#
#    1154     content=content,
#
#    1155     name=call["name"],
#
#    1156     tool_call_id=call["id"],
#
#    1157     status="error",
#
#    1158 )
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:433, in _handle_tool_error(e, flag)
#
#     431     content = flag
#
#     432 elif callable(flag):
#
# --> 433     content = flag(e)  # type: ignore [assignment, call-arg]
#
#     434 else:
#
#     435     msg = (
#
#     436         f"Got unexpected type of `handle_tool_error`. Expected bool, str "
#
#     437         f"or callable. Received: {flag}"
#
#     438     )
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:390, in _default_handle_tool_errors(e)
#
#     388 if isinstance(e, ToolInvocationError):
#
#     389     return e.message
#
# --> 390 raise e
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langgraph\prebuilt\tool_node.py:1104, in ToolNode._execute_tool_async(self, request, input_type, config)
#
#    1102 try:
#
#    1103     try:
#
# -> 1104         response = await tool.ainvoke(call_args, config)
#
#    1105     except ValidationError as exc:
#
#    1106         # Filter out errors for injected arguments
#
#    1107         injected = self._injected_args.get(call["name"])
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_core\tools\structured.py:70, in StructuredTool.ainvoke(self, input, config, **kwargs)
#
#      66 if not self.coroutine:
#
#      67     # If the tool does not implement async, fall back to default implementation
#
#      68     return await run_in_executor(config, self.invoke, input, config, **kwargs)
#
# ---> 70 return await super().ainvoke(input, config, **kwargs)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_core\tools\base.py:652, in BaseTool.ainvoke(self, input, config, **kwargs)
#
#     644 @override
#
#     645 async def ainvoke(
#
#     646     self,
#
#    (...)    649     **kwargs: Any,
#
#     650 ) -> Any:
#
#     651     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
#
# --> 652     return await self.arun(tool_input, **kwargs)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_core\tools\base.py:1131, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#
#    1129 if error_to_raise:
#
#    1130     await run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
#
# -> 1131     raise error_to_raise
#
#    1133 output = _format_output(content, artifact, tool_call_id, self.name, status)
#
#    1134 await run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_core\tools\base.py:1097, in BaseTool.arun(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#
#    1094         tool_kwargs[config_param] = config
#
#    1096     coro = self._arun(*tool_args, **tool_kwargs)
#
# -> 1097     response = await coro_with_context(coro, context)
#
#    1098 if self.response_format == "content_and_artifact":
#
#    1099     msg = (
#
#    1100         "Since response_format='content_and_artifact' "
#
#    1101         "a two-tuple of the message content and raw tool output is "
#
#    1102         f"expected. Instead, generated response is of type: "
#
#    1103         f"{type(response)}."
#
#    1104     )
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\futures.py:286, in Future.__await__(self)
#
#     284 if not self.done():
#
#     285     self._asyncio_future_blocking = True
#
# --> 286     yield self  # This tells Task to wait for completion.
#
#     287 if not self.done():
#
#     288     raise RuntimeError("await wasn't used with future")
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#
#     373 def __wakeup(self, future):
#
#     374     try:
#
# --> 375         future.result()
#
#     376     except BaseException as exc:
#
#     377         # This may also be a cancellation.
#
#     378         self.__step(exc)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\futures.py:199, in Future.result(self)
#
#     197 self.__log_traceback = False
#
#     198 if self._exception is not None:
#
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#
#     200 return self._result
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#
#     300 try:
#
#     301     if exc is None:
#
#     302         # We use the `send` method directly, because coroutines
#
#     303         # don't have `__iter__` and `__next__` methods.
#
# --> 304         result = coro.send(None)
#
#     305     else:
#
#     306         result = coro.throw(exc)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_core\tools\structured.py:124, in StructuredTool._arun(self, config, run_manager, *args, **kwargs)
#
#     122     if config_param := _get_runnable_config_param(self.coroutine):
#
#     123         kwargs[config_param] = config
#
# --> 124     return await self.coroutine(*args, **kwargs)
#
#     126 # If self.coroutine is None, then this will delegate to the default
#
#     127 # implementation which is expected to delegate to _run on a separate thread.
#
#     128 return await super()._arun(
#
#     129     *args, config=config, run_manager=run_manager, **kwargs
#
#     130 )
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\langchain_mcp_adapters\tools.py:58, in convert_mcp_tool_to_langchain_tool.<locals>.call_tool(**arguments)
#
#      55 async def call_tool(
#
#      56     **arguments: dict[str, Any],
#
#      57 ) -> tuple[str | list[str], list[NonTextContent] | None]:
#
# ---> 58     call_tool_result = await session.call_tool(tool.name, arguments)
#
#      59     return _convert_call_tool_result(call_tool_result)
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\client\session.py:225, in ClientSession.call_tool(self, name, arguments)
#
#     221 async def call_tool(
#
#     222     self, name: str, arguments: dict | None = None
#
#     223 ) -> types.CallToolResult:
#
#     224     """Send a tools/call request."""
#
# --> 225     return await self.send_request(
#
#     226         types.ClientRequest(
#
#     227             types.CallToolRequest(
#
#     228                 method="tools/call",
#
#     229                 params=types.CallToolRequestParams(name=name, arguments=arguments),
#
#     230             )
#
#     231         ),
#
#     232         types.CallToolResult,
#
#     233     )
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\mcp\shared\session.py:228, in BaseSession.send_request(self, request, result_type)
#
#     220 jsonrpc_request = JSONRPCRequest(
#
#     221     jsonrpc="2.0",
#
#     222     id=request_id,
#
#     223     **request.model_dump(by_alias=True, mode="json", exclude_none=True),
#
#     224 )
#
#     226 # TODO: Support progress callbacks
#
# --> 228 await self._write_stream.send(JSONRPCMessage(jsonrpc_request))
#
#     230 try:
#
#     231     with anyio.fail_after(
#
#     232         None
#
#     233         if self._read_timeout_seconds is None
#
#     234         else self._read_timeout_seconds.total_seconds()
#
#     235     ):
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\anyio\streams\memory.py:249, in MemoryObjectSendStream.send(self, item)
#
#     247 await checkpoint()
#
#     248 try:
#
# --> 249     self.send_nowait(item)
#
#     250 except WouldBlock:
#
#     251     # Wait until there's someone on the receiving end
#
#     252     send_event = Event()
#
#
#
# File c:\Users\dbyst\miniconda3\Lib\site-packages\anyio\streams\memory.py:218, in MemoryObjectSendStream.send_nowait(self, item)
#
#     206 """
#
#     207 Send an item immediately if it can be done without waiting.
#
#     208
#
#    (...)    215
#
#     216 """
#
#     217 if self._closed:
#
# --> 218     raise ClosedResourceError
#
#     219 if not self._state.open_receive_channels:
#
#     220     raise BrokenResourceError
#
#
#
# ClosedResourceError:
#
# During task with name 'tools' and id 'ab7bcc76-a16e-4b89-4a39-9996fdc4658d'

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

async def run_agent():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        tools = client.get_tools()
        
        agent = create_agent(
            model=llm,
            tools=tools,
            system_prompt="You are a helpful assistant that can answer questions about LangChain, LangGraph, and LangSmith by searching the official documentation."
        )
        
        question = "How do I create a LangChain agent with tools?"
        print(f"Question: {question}\n")
        
        result = await agent.ainvoke({
            "messages": [HumanMessage(content=question)]
        })
        
        print(f"Answer: {result['messages'][-1].content}")

asyncio.get_event_loop().run_until_complete(run_agent())
# Out:
# Question: How do I create a LangChain agent with tools?
#
# Answer: While the documentation links are currently redirecting, I can provide you with a comprehensive guide on creating a LangChain agent with tools based on the latest LangChain practices.
#
# ---
#
# ## Creating a LangChain Agent with Tools
#
# The modern and recommended way to build agents in LangChain is using **LangGraph** (via `langgraph`), but LangChain also provides a simpler `create_react_agent` or `AgentExecutor` approach. Here's how to do both:
#
# ---
#
# ### ✅ Option 1: Modern Approach — Using LangGraph (Recommended)
#
# ```python
# pip install langchain langchain-openai langgraph
# ```
#
# ```python
# from langchain_openai import ChatOpenAI
# from langchain_core.tools import tool
# from langgraph.prebuilt import create_react_agent
#
# # 1. Define your tools
# @tool
# def add(a: int, b: int) -> int:
#     """Add two numbers together."""
#     return a + b
#
# @tool
# def multiply(a: int, b: int) -> int:
#     """Multiply two numbers together."""
#     return a * b
#
# # 2. Initialize the LLM
# llm = ChatOpenAI(model="gpt-4o", temperature=0)
#
# # 3. Create the agent
# tools = [add, multiply]
# agent = create_react_agent(llm, tools)
#
# # 4. Run the agent
# response = agent.invoke({
#     "messages": [{"role": "user", "content": "What is 3 + 5, and then multiply that by 2?"}]
# })
#
# print(response["messages"][-1].content)
# ```
#
# ---
#
# ### ✅ Option 2: Classic Approach — Using `AgentExecutor`
#
# ```python
# from langchain_openai import ChatOpenAI
# from langchain_core.tools import tool
# from langchain.agents import create_tool_calling_agent, AgentExecutor
# from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
#
# # 1. Define your tools
# @tool
# def search_web(query: str) -> str:
#     """Search the web for information."""
#     return f"Results for: {query}"
#
# @tool
# def get_weather(city: str) -> str:
#     """Get the current weather for a city."""
#     return f"The weather in {city} is sunny and 72°F."
#
# tools = [search_web, get_weather]
#
# # 2. Create the prompt
# prompt = ChatPromptTemplate.from_messages([
#     ("system", "You are a helpful assistant."),
#     ("human", "{input}"),
#     MessagesPlaceholder(variable_name="agent_scratchpad"),
# ])
#
# # 3. Initialize the LLM
# llm = ChatOpenAI(model="gpt-4o", temperature=0)
#
# # 4. Create the agent
# agent = create_tool_calling_agent(llm, tools, prompt)
#
# # 5. Wrap in AgentExecutor
# agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)
#
# # 6. Run the agent
# result = agent_executor.invoke({"input": "What's the weather in Paris?"})
# print(result["output"])
# ```
#
# ---
#
# ### 🛠️ Defining Tools — Multiple Ways
#
# #### Using `@tool` decorator (simplest)
# ```python
# from langchain_core.tools import tool
#
# @tool
# def calculator(expression: str) -> str:
#     """Evaluate a math expression."""
#     return str(eval(expression))
# ```
#
# #### Using `StructuredTool` with Pydantic (for complex inputs)
# ```python
# from langchain_core.tools import StructuredTool
# from pydantic import BaseModel
#
# class SearchInput(BaseModel):
#     query: str
#     max_results: int = 5
#
# def search(query: str, max_results: int = 5) -> str:
#     """Search for information."""
#     return f"Top {max_results} results for: {query}"
#
# search_tool = StructuredTool.from_function(
#     func=search,
#     name="search",
#     description="Search the web for information",
#     args_schema=SearchInput,
# )
# ```
#
# #### Using Built-in Tools
# ```python
# from langchain_community.tools import WikipediaQueryRun
# from langchain_community.utilities import WikipediaAPIWrapper
#
# wiki_tool = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
# tools = [wiki_tool]
# ```
#
# ---
#
# ### 🔑 Key Concepts
#
# | Concept | Description |
# |---|---|
# | **Tool** | A function the agent can call, with a name and description |
# | **LLM** | The model that decides which tool to use |
# | **Agent** | The logic that loops: think → act → observe |
# | **AgentExecutor** | Runs the agent loop until a final answer is reached |
# | **ReAct** | The most common agent pattern (Reason + Act) |
#
# ---
#
# ### 💡 Tips
# - **Always write clear docstrings** for your tools — the LLM uses them to decide when to call a tool.
# - Use `verbose=True` in `AgentExecutor` to see the agent's reasoning steps.
# - For production use, prefer **LangGraph's `create_react_agent`** as it offers more control, streaming, and memory support.
# - Set `handle_parsing_errors=True` in `AgentExecutor` to gracefully handle LLM output errors.
#
# Would you like more details on any specific part, such as adding memory, streaming responses, or using specific built-in tools?

# %% [markdown]
# ### Accessing MCP Resources
#
# MCP resources provide read-only access to data. The `get_resources()` method returns LangChain `Blob` objects.
#
# You can optionally filter by server name or specific URIs:

# %%
# Access MCP resources
# get_resources() is also stateless — no context manager needed
# mcp_resources = await mcp_client.get_resources()
from langchain_mcp_adapters.client import MultiServerMCPClient
print([m for m in dir(MultiServerMCPClient) if not m.startswith('_')])
# Out:
# ['connect_to_server', 'connect_to_server_via_sse', 'connect_to_server_via_stdio', 'get_tools']

# %%
#mcp_tools = await mcp_client.get_tools()

async def run_workflow():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        
        # Get tools
        tools = client.get_tools()
        print(f"Loaded {len(tools)} tools: {[t.name for t in tools]}")
        
        # Get resources (if available)
        if hasattr(client, 'get_resources'):
            resources = await client.get_resources()
            print(f"Resources: {resources}")
        
        # Create agent
        agent = create_agent(
            model=llm,
            tools=tools,
            system_prompt="You are a helpful assistant that answers questions about LangChain by searching the official documentation."
        )
        
        # Run a query
        question = "How do I create a LangChain agent with tools?"
        result = await agent.ainvoke({
            "messages": [HumanMessage(content=question)]
        })
        print(f"\nAnswer: {result['messages'][-1].content}")

asyncio.get_event_loop().run_until_complete(run_workflow())
# Out:
# Loaded 2 tools: ['list_doc_sources', 'fetch_docs']
#
# Answer: Based on my knowledge of LangChain's official documentation, here is a comprehensive guide on how to create a LangChain agent with tools:
#
# ---
#
# ## Creating a LangChain Agent with Tools
#
# The modern recommended way to build agents in LangChain is using **LangGraph**, which provides more control and flexibility. Here's how to do it:
#
# ---
#
# ### 1. Install Dependencies
#
# ```bash
# pip install langchain langchain-openai langgraph
# ```
#
# ---
#
# ### 2. Define Your Tools
#
# Tools are functions the agent can call. You can use the `@tool` decorator:
#
# ```python
# from langchain_core.tools import tool
#
# @tool
# def add(a: int, b: int) -> int:
#     """Add two numbers together."""
#     return a + b
#
# @tool
# def multiply(a: int, b: int) -> int:
#     """Multiply two numbers together."""
#     return a * b
#
# tools = [add, multiply]
# ```
#
# You can also use **built-in tools** like Tavily Search:
# ```python
# from langchain_community.tools.tavily_search import TavilySearchResults
#
# search_tool = TavilySearchResults(max_results=3)
# tools = [search_tool]
# ```
#
# ---
#
# ### 3. Set Up the LLM with Tool Binding
#
# Bind the tools to your LLM so it knows what's available:
#
# ```python
# from langchain_openai import ChatOpenAI
#
# llm = ChatOpenAI(model="gpt-4o", temperature=0)
# llm_with_tools = llm.bind_tools(tools)
# ```
#
# ---
#
# ### 4. Create the Agent with LangGraph (Recommended)
#
# ```python
# from langgraph.prebuilt import create_react_agent
#
# # Create the agent
# agent = create_react_agent(llm, tools)
#
# # Run the agent
# result = agent.invoke({
#     "messages": [("human", "What is 3 multiplied by 5?")]
# })
#
# print(result["messages"][-1].content)
# ```
#
# ---
#
# ### 5. Add Memory (Optional)
#
# To give your agent conversational memory:
#
# ```python
# from langgraph.checkpoint.memory import MemorySaver
#
# memory = MemorySaver()
# agent = create_react_agent(llm, tools, checkpointer=memory)
#
# config = {"configurable": {"thread_id": "my-session"}}
#
# # First turn
# agent.invoke({"messages": [("human", "My name is Alice.")]}, config=config)
#
# # Second turn — agent remembers context
# agent.invoke({"messages": [("human", "What's my name?")]}, config=config)
# ```
#
# ---
#
# ### 6. Add a System Prompt (Optional)
#
# ```python
# from langchain_core.messages import SystemMessage
#
# system_message = SystemMessage(content="You are a helpful math assistant.")
# agent = create_react_agent(llm, tools, state_modifier=system_message)
# ```
#
# ---
#
# ### 7. Stream Agent Output (Optional)
#
# ```python
# for chunk in agent.stream({"messages": [("human", "What is 10 + 25?")]}):
#     print(chunk)
# ```
#
# ---
#
# ### Key Concepts
#
# | Concept | Description |
# |---|---|
# | **Tool** | A function the agent can call, defined with `@tool` or from built-in integrations |
# | **LLM with tools** | An LLM that has been made aware of available tools via `.bind_tools()` |
# | **ReAct Agent** | A reasoning + acting loop where the agent decides when and which tools to call |
# | **LangGraph** | The recommended framework for building stateful, controllable agents |
#
# ---
#
# ### Tips
# - Use **`@tool`** with clear docstrings — the LLM uses the docstring to understand what the tool does.
# - Prefer **LangGraph's `create_react_agent`** over the legacy `AgentExecutor` for new projects.
# - Use **`MemorySaver`** for multi-turn conversations.
# - Always use a model that supports **tool/function calling** (e.g., GPT-4o, Claude 3, Gemini).
#
# Would you like more details on any specific part, such as custom tools, tool error handling, or building more complex multi-agent systems?

# %%
mcp_tools
# Out:
# [StructuredTool(name='list_doc_sources', description='List all available documentation sources.\n\nThis is the first tool you should call in the documentation workflow.\nIt provides URLs to llms.txt files or local file paths that the user has made available.\n\nReturns:\n    A string containing a formatted list of documentation sources with their URLs or file paths\n', args_schema={'properties': {}, 'title': 'list_doc_sourcesArguments', 'type': 'object'}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001A0BFBB0720>),
#  StructuredTool(name='fetch_docs', description="Fetch and parse documentation from a given URL or local file.\n\nUse this tool after list_doc_sources to:\n1. First fetch the llms.txt file from a documentation source\n2. Analyze the URLs listed in the llms.txt file\n3. Then fetch specific documentation pages relevant to the user's question\n\nArgs:\n    url: The URL to fetch documentation from.\n\nReturns:\n    The fetched documentation content converted to markdown, or an error message\n    if the request fails or the URL is not from an allowed domain.", args_schema={'properties': {'url': {'title': 'Url', 'type': 'string'}}, 'required': ['url'], 'title': 'fetch_docsArguments', 'type': 'object'}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001A0BFBB05E0>)]

# %% [markdown]
# ### Middleware and Tool Interceptors
#
# One of the powerful features of `langchain-mcp-adapters` is the ability to use tool interceptors (middleware) to customize tool behavior. This allows you to:
#
# - **Log tool calls**: Track when and how tools are used
# - **Modify requests/responses**: Transform tool inputs or outputs
# - **Add validation**: Ensure tool inputs meet certain criteria
# - **Implement retry logic, caching, or rate limiting**
#
# Interceptors follow a handler callback pattern (similar to middleware in web frameworks). Any async callable matching the `(request, handler) -> result` signature works. Interceptors compose in an "onion" pattern where the first interceptor is the outermost layer.
#
# Let's create a simple tool interceptor that logs tool usage:

# %% [markdown]
# !!!tool_interceptors is not a valid parameter for MultiServerMCPClient in your version.
#
# OLD code provided by IRONHACK
# from langchain_mcp_adapters.client import MultiServerMCPClient
#
# # Tool interceptors are async callables with signature:
# #   async def interceptor(request, handler) -> result
# # - request: MCPToolCallRequest with .name and .arguments
# # - handler: callable to invoke the next interceptor or the actual tool
# # - return: MCPToolCallResult
#
# async def logging_interceptor(request, handler):
#     """Interceptor that logs tool calls and responses."""
#     print(f"[LOG] Tool '{request.name}' called with input: {request.args}")
#     result = await handler(request)
#     print(f"[LOG] Tool '{request.name}' returned result: {str(result.content)[:100]}...")
#     return result
#
# # Create MCP client with tool interceptor
# # Pass interceptors as a list via the tool_interceptors parameter
# mcp_client_with_logging = MultiServerMCPClient(
#     {
#         "langchain-docs": {
#             "transport": "http",
#             "url": "https://docs.langchain.com/mcp"
#         }
#     },
#     tool_interceptors=[logging_interceptor]
# )
#
# print("MCP client configured with logging interceptor")

# %%
import inspect
from langchain_mcp_adapters.client import MultiServerMCPClient
print(inspect.signature(MultiServerMCPClient.__init__))
# Out:
# (self, connections: dict[str, langchain_mcp_adapters.client.StdioConnection | langchain_mcp_adapters.client.SSEConnection] = None) -> None

# %%
#added interceptors
from langchain_mcp_adapters.client import MultiServerMCPClient
import asyncio

async def logging_interceptor(request, handler):
    """Interceptor that logs tool calls and responses."""
    print(f"[LOG] Tool '{request.name}' called with input: {request.args}")
    result = await handler(request)
    print(f"[LOG] Tool '{request.name}' returned result: {str(result.content)[:100]}...")
    return result

def wrap_tool_with_logging(tool):
    original_run = tool._run
    
    def logged_run(*args, **kwargs):
        print(f"[LOG] Tool '{tool.name}' called with: {args} {kwargs}")
        result = original_run(*args, **kwargs)
        print(f"[LOG] Tool '{tool.name}' returned: {str(result)[:100]}...")
        return result
    
    tool._run = logged_run
    return tool

async def run_with_logging():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        tools = [wrap_tool_with_logging(t) for t in client.get_tools()]
        print(f"MCP client configured with logging interceptor")
        print(f"Loaded {len(tools)} tools with logging: {[t.name for t in tools]}")
        return tools

mcp_tools_logged = asyncio.get_event_loop().run_until_complete(run_with_logging())
# Out:
# MCP client configured with logging interceptor
# Loaded 2 tools with logging: ['list_doc_sources', 'fetch_docs']

# %% [markdown]
# ### Complete Example: Agent with Logging
#
# Let's create a complete example that uses the logging interceptor.
#
# OLD BROKEN CODE BY IRONHACK!
# # Get tools (interceptor will log tool calls)
# tools = await mcp_client_with_logging.get_tools()
#
# # Create agent
# agent = create_agent(
#     model=llm,
#     tools=tools,
#     system_prompt="You are a helpful assistant that answers questions about LangChain documentation."
# )
#
# # Ask a question
# question = "What is LangChain and what are its main features?"
# print(f"\nQuestion: {question}\n")
# print("=" * 60)
#
# result = await agent.ainvoke({
#     "messages": [HumanMessage(content=question)]
# })
#
# print("=" * 60)
# print(f"\nFinal Answer:\n{result['messages'][-1].content}")

# %%
async def run_with_logging():
    async with MultiServerMCPClient({
        "langchain-docs": {
            "transport": "sse",
            "url": "http://localhost:8082/sse"
        }
    }) as client:
        
        tools = [wrap_tool_with_logging(t) for t in client.get_tools()]
        
        agent = create_agent(
            model=llm,
            tools=tools,
            system_prompt="You are a helpful assistant that answers questions about LangChain documentation."
        )
        
        question = "What is LangChain and what are its main features?"
        print(f"\nQuestion: {question}\n")
        print("=" * 60)
        
        result = await agent.ainvoke({
            "messages": [HumanMessage(content=question)]
        })
        
        print("=" * 60)
        print(f"\nFinal Answer:\n{result['messages'][-1].content}")

asyncio.get_event_loop().run_until_complete(run_with_logging())
# Out:
# Question: What is LangChain and what are its main features?
#
# ============================================================
# ============================================================
#
# Final Answer:
# Based on my knowledge of LangChain and its documentation, here is a comprehensive overview:
#
# ---
#
# ## What is LangChain?
#
# **LangChain** is an open-source framework designed to simplify the development of applications powered by **Large Language Models (LLMs)**. It provides a standard interface and a rich set of tools for building context-aware, reasoning-driven applications by connecting LLMs to external data sources, tools, and workflows.
#
# ---
#
# ## Main Features
#
# ### 1. 🔗 Composable Chains (LCEL)
# LangChain Expression Language (LCEL) allows developers to compose complex pipelines (called **chains**) by linking together components like prompts, models, parsers, and retrievers in a declarative and readable way.
#
# ### 2. 🤖 LLM & Chat Model Integrations
# LangChain supports a wide variety of LLM providers (OpenAI, Anthropic, Google, Hugging Face, Cohere, etc.), offering a **unified interface** to interact with them regardless of the underlying provider.
#
# ### 3. 📄 Prompt Management
# It provides tools for creating, managing, and optimizing **prompt templates**, including few-shot prompting, dynamic prompts, and chat prompt templates.
#
# ### 4. 🗂️ Retrieval-Augmented Generation (RAG)
# LangChain has robust support for **RAG pipelines**, enabling applications to retrieve relevant documents from vector stores or other data sources and inject them into LLM prompts for grounded, accurate responses.
#
# ### 5. 🧠 Memory
# LangChain supports various types of **memory** (conversation buffer, summary memory, etc.) to give LLMs the ability to remember past interactions within a session or across sessions.
#
# ### 6. 🛠️ Agents & Tools
# LangChain enables the creation of **agents** — LLMs that can reason and decide which **tools** (e.g., web search, calculators, APIs, databases) to use to complete a task dynamically.
#
# ### 7. 📦 Document Loaders & Text Splitters
# It includes utilities to **load documents** from various sources (PDFs, web pages, databases, etc.) and **split** them into manageable chunks for processing.
#
# ### 8. 🗄️ Vector Store Integrations
# LangChain integrates with popular **vector databases** (Pinecone, Chroma, FAISS, Weaviate, etc.) for storing and retrieving embeddings efficiently.
#
# ### 9. 📊 Callbacks & Observability
# LangChain provides a **callbacks system** for logging, monitoring, and tracing the execution of chains and agents, with native integration with **LangSmith** for debugging and evaluation.
#
# ### 10. 🌐 LangSmith & LangGraph Ecosystem
# - **LangSmith**: A platform for testing, evaluating, and monitoring LLM applications.
# - **LangGraph**: An extension for building **stateful, multi-actor** applications and complex agent workflows using graph-based structures.
#
# ---
#
# ## Summary
#
# LangChain is essentially the **glue** that connects LLMs to the real world — making it easier to build production-ready AI applications like chatbots, question-answering systems, autonomous agents, summarization tools, and much more. It is available in both **Python** and **JavaScript/TypeScript**.

# %% [markdown]
# ### Key Takeaways
#
# 1. **langchain-mcp-adapters** provides a seamless way to integrate MCP servers with LangChain
# 2. **MultiServerMCPClient** accepts a dict of server configurations — no separate parameter classes needed
# 3. **Stateless by default** — each `get_tools()` or `get_resources()` call handles sessions internally, no `async with` needed
# 4. **HTTP Transport** is used for web-based MCP servers like the LangChain documentation server
# 5. **Tool Interceptors** are async callables with `(request, handler) -> result` signature, passed via `tool_interceptors=`
# 6. **`create_react_agent`** uses the `prompt` parameter (not `state_modifier`, which is deprecated)
#
# ### Documentation References
#
# - **LangChain Documentation MCP**: `https://docs.langchain.com/mcp`
# - **Documentation Index**: `https://docs.langchain.com/llms.txt`
# - **langchain-mcp-adapters**: [LangChain MCP Documentation](https://docs.langchain.com/oss/python/langchain/mcp)
# - **API Reference**: [langchain-mcp-adapters Reference](https://reference.langchain.com/python/langchain_mcp_adapters/)
#
# ### Next Steps
#
# - Explore other MCP servers from the [official MCP servers repository](https://github.com/modelcontextprotocol/servers)
# - Build custom tool interceptors for your specific use cases
# - Combine multiple MCP servers for comprehensive agent capabilities
